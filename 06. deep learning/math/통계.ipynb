# %% [markdown]
# # 통계란?
# 통계는 데이터의 수집, 분석, 추론, 요약 등의 방법론을 다룬다.

# %% [markdown]
# - Design(설계/계획)
# - Description(요약)
# 데이터를 요약 표현하기 위한 시각적(Graphical), 수치적(numerical) 방법
# - Inference(추론)
# 표본에 기반한 모집단에 대한 추론/예측

# %% [markdown]
# # [모집단/모수/표본/통계량](https://www.youtube.com/watch?v=XP4cMk1iMUs)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 모집단(Poplulation)
# 통계학에서 관심/조사의 대상이 되는 개체의 전체 집합

# %% [markdown]
# ## 모수(Parameter)
# 모집단에 대한 수치적 요약
# - 고등학생의 1일 평균 온라인게임 플레이 시간
# - 강아지보다 고양이를 좋아하는 성인의 비율

# %% [markdown]
# ## 표본(Sample)
# 모집단을 적절히 대표하는 모집단의 일부

# %% [markdown]
# ## 통계량(Statistic)
# 표본에 대한 수치적 요약
# - 고등학생 1000명의 1일 평균 온라인게임 플레이 시간
# - 강아지보다 고양이를 좋아하는 성인의 비율(1000명)
#
# Sample statistic(표본 통계량)을 통해서 Population parameter(모집단 모수)를 예측하고 이해하는 과정이 통계의 목적이라고 생각하면 된다.

# %% [markdown]
# # [자료의 종류](https://lucete1504.tistory.com/12)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 범주형 자료
# 속성의 범주화, 상대적 서열도 표현
# - 명복형 자료: 단순히 속성을 분류하기 위함(혈액형)
# - 순서형 자료: 상대적인 크기 비교(만족도, 최종학력, 학점)

# %% [markdown]
# ## 양적 자료
# 자료자체가 숫자로 표현됨
# - 이산형 자료: 셀 수 있음 (빈도수, 불량품의 수)
# - 연속형 자료: 셀 수 없음 (길이, 시간)

# %% [markdown]
# # 통계량

# %% [markdown]
# ## 중심

# %% [markdown]
# ### 최빈값(mode)
# - 발생빈도가 가장 높은 값
# - 극단값에 영향을 받지 않음
# - 주로 범주형 자료에 대한 대표값
# - 2개 이상 존재 가능

# %% [markdown]
# ### 중앙값(median)
# - 크기 순으로 정렬된 자료에서 가운데에 위치하는 값
# - 관측값 변화에 민감하지 않음
# - 극단값에 영향을 받지 않음

# %% [markdown]
# ### 산술평균(Arithmetic Mean)
# - 모든 자료의 값을 더하여 자료의 수로 나누어 준 값
# - 모든 값을 반영하므로 극단값에 영향을 받음
# $$
# \bar{x} = { \sum{x_i} \over n } = { x_1 + x_2 + ... + x_n \over n }
# $$

# %% [markdown]
# ### 가중평균(Weighted Mean)
# - 자료의 중요성이 각기 다를 경우
# - 중요도에 따라 가중치를 부여한 평균
# $$
# \bar{X} = { \sum{w_i\bar{X_i}} \over \sum{w_i} } = { w_1\bar{X_1} + w_2\bar{X_2} + ... + w_i\bar{X_i} \over w_1 + w_2 + ... + w_i}
# $$

# %% [markdown]
# ### [기하평균(Geometric Mean)](https://www.oppadu.com/%EC%97%91%EC%85%80-%EA%B8%B0%ED%95%98%ED%8F%89%EA%B7%A0/)
# - 자료가 성장률, 증가율 등 앞 시점에 대한 비율로 나타난 경우 유용한 통계량
# - 음수가 아닌 자료값 only
# - 연간 물가 상승률
# Ex) 일일 주가 상승률: 1% 3% 5% 10% : 1.0374....
#
# $$
# 기하평균(G) = \sqrt[n]{ \prod^n x_i }
# $$
# $$
# (x_i = 상승률)
# $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 산포

# %% [markdown]
# # 확률과 확률변수

# %% [markdown]
# # 이산확률 분포

# %% [markdown]
# # 연속확률 분포

# %% [markdown]
# # 카이제곱 분포

# %% [markdown]
# # 통계적 추정

# %% [markdown]
# # 통계검정

# %% [markdown]
# # 통계 - 참고 문서들
# [Khan Academy] 확률과 통계
# - https://ko.khanacademy.org/math/statistics-probability
#
# [고려대 통계학과] 통계 기초 개념과 공식
# - https://youtube.com/watch?v=YaCQrJCgbqg&feature=share
# - https://www.youtube.com/watch?v=JgqZNWKKr98

# %% [markdown]
# ## [최대우도법](https://www.youtube.com/watch?v=XhlfVtGb19c)

# %% [markdown]
# ## [F-value와 분산분석(ANOVA)](https://www.youtube.com/watch?v=VZ6WPnI82Z8)
