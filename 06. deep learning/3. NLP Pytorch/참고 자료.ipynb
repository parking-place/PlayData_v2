# %% [markdown]
# - https://learn.microsoft.com/en-us/training/modules/intro-natural-language-processing-pytorch/
# - https://github.com/graykode/nlp-tutorial

# %% [markdown]
# bert
# - https://mindscale.kr/course/nlg/66/
# - https://github.com/huggingface/transformers
# - https://huggingface.co/bert-base-uncased

# %% [markdown]
# # 추가학습
# - [RNN 개념](https://www.youtube.com/watch?v=Hn3GHHOXKCE)
# - [word2vec](https://www.youtube.com/watch?v=TZaeSgAWXL8)
# - [lstm, gru](https://www.youtube.com/watch?v=rbk9XFaoCEE)
# - [텍스트 전처리](https://www.youtube.com/watch?v=vlzeMC5m5A8)
# - [유사도](https://www.youtube.com/watch?v=9ea7Ja52ezQ)
